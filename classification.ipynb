# %%
#點兩下編輯
#分類
#資料集

#抓取圖片
![](http://www.sevenapex.com/sevenapex/wp-content/uploads/2016/10/1243240237Iris_hollandica_blue_magic_bloem2-e1476958011663-300x365.jpg)

#無!為超連結
[Markdown](https://www.google.com/)

```python
print('hello world)
```

$半圓面積=\frac{1}{2}\times\pi R^2 $

# %% [markdown]
# -v

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris["data"],columns = iris["feature_names"])
df["ans"] = iris["target"]
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      ans
# 0      0
# 1      0
# ...

# %%
from sklearn.model_selection import train_test_split
#[90%題目, 10%題目, 90%答案, 10%答案]
x_train, x_test, y_train, y_test = train_test_split(iris["data"],
                iris["target"],
                test_size=0.1) #10%作為測試

# %%
#選擇學習方式
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()

# %%
#開始作考古題驗證fit
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
#驗證模型
from sklearn.metrics import accuracy_score
pre = clf.predict(x_test)
print("預測:",list(pre))
print("正確:",list(y_test))
print("正確率:",accuracy_score(pre,y_test))
# Out:
# 預測: [0, 0, 2, 1, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 2]
# 正確: [0, 0, 1, 1, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 2]
# 正確率: 0.9333333333333333

# %%
#安裝graphviz -> 設定環境變數到graphviz/bin -> install packages "graphviz"
from sklearn.tree import export_graphviz
import graphviz
g = export_graphviz(clf, feature_names=iris["feature_names"], 
                    class_names=iris["target_names"],
                   filled=True) #顏色
graphviz.Source(g)
